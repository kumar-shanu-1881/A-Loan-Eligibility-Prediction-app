# %%
# import required libraries
import pandas as pd
import numpy as np

# %%
# Load the raw data
url=r"../data\new_Loan_Default.csv"
df=pd.read_csv(url)

# %%
print(df.head())
# Out:
#    Age   Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   62   212071      525911          702              82               5
# 1   29  2693541     4693806          674              83               8
# 2   49  1175104      520477          714             289              11
# 3   63   383571      982506          678             216               9
# 4   66    39961       29965          478             111               4
#
#    InterestRate  LoanTerm  DTIRatio EmploymentType HasMortgage LoanPurpose  \
# 0         20.00        84      0.15      Full-time          No   Education
# 1         17.56       180      0.12  Self-employed         Yes       Other
# 2         16.34       240      0.37      Part-time          No    Personal
# 3         15.34        24      0.70      Full-time          No        Home
# 4         19.59        48      0.58  Self-employed          No        Auto
#
#   HasCoSigner  Default      LoanID Education MaritalStatus HasDependents
# ...

# %%
print(df.shape)
# Out:
# (380347, 18)

# %%
#display the Overview of the dataset 
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380347 entries, 0 to 380346
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Age             380347 non-null  int64
#  1   Income          380347 non-null  int64
#  2   LoanAmount      380347 non-null  int64
#  3   CreditScore     380347 non-null  int64
#  4   MonthsEmployed  380347 non-null  int64
#  5   NumCreditLines  380347 non-null  int64
#  6   InterestRate    380347 non-null  float64
#  7   LoanTerm        380347 non-null  int64
#  8   DTIRatio        380347 non-null  float64
#  9   EmploymentType  380347 non-null  object
#  10  HasMortgage     380347 non-null  object
#  11  LoanPurpose     380347 non-null  object
#  12  HasCoSigner     380347 non-null  object
#  13  Default         380347 non-null  int64
#  14  LoanID          255347 non-null  object
#  15  Education       255347 non-null  object
# ...

# %%
print(df.describe())

# df.drop_duplicates()
# Out:
#                  Age        Income    LoanAmount    CreditScore  \
# count  380347.000000  3.803470e+05  3.803470e+05  380347.000000
# mean       43.682287  6.173828e+05  1.049849e+06     605.217028
# std        15.103895  1.211412e+06  1.983803e+06     144.392717
# min        18.000000  1.500000e+04  5.000000e+03     300.000000
# 25%        31.000000  6.530250e+04  9.511900e+04     498.000000
# 50%        44.000000  1.155330e+05  1.841700e+05     630.000000
# 75%        57.000000  6.426110e+05  9.277305e+05     717.000000
# max        70.000000  1.000000e+07  1.000000e+07     850.000000
#
#        MonthsEmployed  NumCreditLines   InterestRate       LoanTerm  \
# count   380347.000000   380347.000000  380347.000000  380347.000000
# mean        88.426308        3.817346      14.447828      68.085385
# std         88.012897        2.877269       6.962001      81.261421
# min          0.000000        1.000000       2.000000      12.000000
# ...

# %%
df[
    (df["Income"] > 500000) &
    (df["CreditScore"] > 740)
]["Default"].value_counts(normalize=True)
# Out:
# Default
# 1    0.652675
# 0    0.347325
# Name: proportion, dtype: float64

# %%
df[
    (df["Income"] > 500000) &
    (df["LoanAmount"] > 200000)
]["Default"].value_counts(normalize=True)
# Out:
# Default
# 1    0.73291
# 0    0.26709
# Name: proportion, dtype: float64

# %%
print(df['Default'].value_counts(normalize=True)*100)
# Out:
# Default
# 0    68.234533
# 1    31.765467
# Name: proportion, dtype: float64

# %%
df.drop_duplicates()
# Out:
#         Age   Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0        62   212071      525911          702              82               5
# 1        29  2693541     4693806          674              83               8
# 2        49  1175104      520477          714             289              11
# 3        63   383571      982506          678             216               9
# 4        66    39961       29965          478             111               4
# ...     ...      ...         ...          ...             ...             ...
# 380342   36   125318      177318          719              57               1
# 380343   61    73111       25518          645              74               3
# 380344   66   139373      233111          413              20               4
# 380345   64    44046       33229          534              62               2
# 380346   50  1704187     6088211          667             241               5
#
# ...

# %%
print(df.isnull().sum())
# Out:
# Age                    0
# Income                 0
# LoanAmount             0
# CreditScore            0
# MonthsEmployed         0
# NumCreditLines         0
# InterestRate           0
# LoanTerm               0
# DTIRatio               0
# EmploymentType         0
# HasMortgage            0
# LoanPurpose            0
# HasCoSigner            0
# Default                0
# LoanID            125000
# Education         125000
# MaritalStatus     125000
# HasDependents     125000
# dtype: int64

# %% [markdown]
# Detecting Outliers

# %%
# Define the numerical columns to check
num_cols = [
    "Age",
    "Income",
    "LoanAmount",
    "CreditScore",
    "MonthsEmployed",
    "NumCreditLines",
    "InterestRate",
    "LoanTerm",
    "DTIRatio",
]

print(f"Original shape: {df.shape}")

# 1. Calculate IQR bounds
Q1 = df[num_cols].quantile(0.25)
Q3 = df[num_cols].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# 2. Create a boolean mask for rows that contain any outlier
outlier_mask = ((df[num_cols] < lower_bound) | (df[num_cols] > upper_bound)).any(
    axis=1
)

# 3. Filter and print the outliers
outliers_df = df[outlier_mask]
print(f"\n--- DETECTED OUTLIERS ({len(outliers_df)} rows) ---")
if not outliers_df.empty:
    print(outliers_df[["LoanID"] + num_cols])
else:
    print("No outliers detected in this slice of data.")

# 4. Drop the outliers and update the main DataFrame
df = df[~outlier_mask].copy()

print(f"\nUpdated shape (outliers removed): {df.shape}")
# Out:
# Original shape: (380347, 18)
#
# --- DETECTED OUTLIERS (112419 rows) ---
#        LoanID  Age   Income  LoanAmount  CreditScore  MonthsEmployed  \
# 1         NaN   29  2693541     4693806          674              83
# 2         NaN   49  1175104      520477          714             289
# 3         NaN   63   383571      982506          678             216
# 6         NaN   69  1489291      885520          654             110
# 10        NaN   57  2638388     2080335          647             150
# ...       ...  ...      ...         ...          ...             ...
# 380311    NaN   29  1963919     3233582          664              27
# 380326    NaN   68  3108025     1253898          459             188
# 380336    NaN   59   150000      501221          673             280
# 380338    NaN   61   743015      253342          636             287
# 380346    NaN   50  1704187     6088211          667             241
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio
# ...

# %%
print(df.columns)


num_cols=df.select_dtypes(include=['int64','float64']).columns
cat_cols=df.select_dtypes(include=['object']).columns
# Out:
# Index(['Age', 'Income', 'LoanAmount', 'CreditScore', 'MonthsEmployed',
#        'NumCreditLines', 'InterestRate', 'LoanTerm', 'DTIRatio',
#        'EmploymentType', 'HasMortgage', 'LoanPurpose', 'HasCoSigner',
#        'Default', 'LoanID', 'Education', 'MaritalStatus', 'HasDependents'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Income'], kde=True)
plt.show()

# %%
df['Education'].value_counts()
sns.countplot(x='Education', data=df)
plt.show()

# %%
sns.boxplot(x='Default', y='Income', data=df)
plt.show()

# %%
sns.countplot(x='EmploymentType', hue='Default', data=df)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df[num_cols].corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
sns.boxplot(df['LoanAmount'])
plt.show()

# %% [markdown]
# drop noises

# %%
df=df.drop(columns=['LoanID','MaritalStatus','Education','HasDependents'])

# %%
# save the cleaned dataset 
df.to_csv(r'../data\cleaned_data.csv')
